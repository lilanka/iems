# %%
import pandapower.networks as pn

# %%
net = pn.create_cigre_network_mv(with_der="all")

# %%
net
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (15 elements)
#    - load (18 elements)
#    - sgen (13 elements)
#    - storage (2 elements)
#    - switch (8 elements)
#    - ext_grid (1 element)
#    - line (15 elements)
#    - trafo (2 elements)
#    - bus_geodata (15 elements)

# %%
net.sgen
# Out:
#                        name  bus   p_mw  q_mvar  sn_mva  scaling  in_service  \
# 0                      PV 3    3  0.020     0.0   0.020      1.0        True
# 1                      PV 4    4  0.020     0.0   0.020      1.0        True
# 2                      PV 5    5  0.030     0.0   0.030      1.0        True
# 3                      PV 6    6  0.030     0.0   0.030      1.0        True
# 4                      PV 8    8  0.030     0.0   0.030      1.0        True
# 5                      PV 9    9  0.030     0.0   0.030      1.0        True
# 6                     PV 10   10  0.040     0.0   0.040      1.0        True
# 7                     PV 11   11  0.010     0.0   0.010      1.0        True
# 8                     WKA 7    7  1.500     0.0   1.500      1.0        True
# 9   Residential fuel cell 1    5  0.033     0.0   0.033      1.0        True
# 10             CHP diesel 1    9  0.310     0.0   0.310      1.0        True
# ...

# %%
net.sgen['p_mw'][4] = 5

# %%
net.sgen
# Out:
#                        name  bus   p_mw  q_mvar  sn_mva  scaling  in_service  \
# 0                      PV 3    3  0.020     0.0   0.020      1.0        True
# 1                      PV 4    4  0.020     0.0   0.020      1.0        True
# 2                      PV 5    5  0.030     0.0   0.030      1.0        True
# 3                      PV 6    6  0.030     0.0   0.030      1.0        True
# 4                      PV 8    8  5.000     0.0   0.030      1.0        True
# 5                      PV 9    9  0.030     0.0   0.030      1.0        True
# 6                     PV 10   10  0.040     0.0   0.040      1.0        True
# 7                     PV 11   11  0.010     0.0   0.010      1.0        True
# 8                     WKA 7    7  1.500     0.0   1.500      1.0        True
# 9   Residential fuel cell 1    5  0.033     0.0   0.033      1.0        True
# 10             CHP diesel 1    9  0.310     0.0   0.310      1.0        True
# ...

# %%
solarRatings = []
